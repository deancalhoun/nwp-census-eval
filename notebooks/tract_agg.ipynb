# %%
import numpy as np
import pandas as pd
import xarray as xr
import geopandas as gpd
import xagg

# %%
gdf = gpd.read_file('/Users/dcalhoun/Desktop/Research/Data/census/shapefiles/nhgis0001_shapefile_tl2023_us_tract_2023/US_tract_2023.shp')

# %%
gdf['GEOID']
# Out:
# 0        01001020100
# 1        01001020200
# 2        01001020300
# 3        01001020400
# 4        01001020501
#             ...
# 85069    72153750501
# 85070    72153750502
# 85071    72153750503
# 85072    72153750601
# 85073    72153750602
# Name: GEOID, Length: 85074, dtype: object
